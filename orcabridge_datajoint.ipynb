# %%
from orcabridge.operation import Tracker
from orcabridge.source import GlobSource
import orcabridge.mapper as m

# %%
dataset1 = GlobSource('data', './examples/dataset2/*.bin')

# %%
for t, v in dataset1.forward():
    print(t, v)

# %%
dataset1

# %%
for tag, packet in dataset1():
    print(tag, packet)

# %%
dataset1

# %%
tracker = Tracker()
with tracker:
    mapped_dataset = m.MapKeys({'data': 'bin_data'})(dataset1)
    stream2 = m.MapTags({'file_name': 'source_name'})(mapped_dataset)
    mixed = m.Join()(mapped_dataset, stream2)

# %%
for tag, packet in dataset1:
    print(tag, packet)

# %%
for tag, packet in mapped_dataset:
    print(f'Tag {tag} has {lekkkk

# %%
tracker.operations
# Out:
# {(<orcabridge.source.GlobSource at 0x7f2110337490>, ''): [],
#  (<orcabridge.mapper.MapKeys at 0x7f206ed2c3d0>,
#   '-383813637390442437'): [(<orcabridge.source.GlobSource at 0x7f2110337490>,
#    '')],
#  (<orcabridge.mapper.MapTags at 0x7f206ed2f7c0>,
#   '31070740819472215'): [(<orcabridge.mapper.MapKeys at 0x7f206ed2c3d0>,
#    '-383813637390442437')],
#  (<orcabridge.mapper.Join at 0x7f211034b580>,
#   '31070740819472215:8628924679229345476'): [(<orcabridge.mapper.MapKeys at 0x7f206ed2c3d0>,
#    '-383813637390442437'),
#   (<orcabridge.mapper.MapTags at 0x7f206ed2f7c0>, '31070740819472215')]}

# %%
import networkx as nx
G = nx.DiGraph()
for k in tracker.operations:
    G.add_node(k)

for k, sources in tracker.operations.items():
    for source in sources:
        G.add_edge(source, k)

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(111)
nx.draw(G, with_labels=True)

# %%
tracker.operations
# Out:
# {<orcabridge.source.GlobSource at 0x7efe09e3fb50>: {'': []},
#  <orcabridge.mapper.MapKeys at 0x7efe09e517b0>: {'-7508858011780440321': [(<orcabridge.source.GlobSource at 0x7efe09e3fb50>,
#     '')]}}

# %%
schema = dj.schema('enigma_orca_bridge_test')

# %%
@schema
class BehavioralData(dj.Lookup):
    definition = """
    subject_id: int unsigned
    session_datetime: datetime
    ---
    behavior_data: varchar(128)  # path to behavioral data
    """
    contents = [
        (1, '2023-10-01 12:00:00', 'path/to/behavior_data_1'),
        (2, '2023-10-02 13:00:00', 'path/to/behavior_data_2'),
    ]

# %%
for tag, packet in behavior_data.proj(..., animal_id='subject_id'):
    print(f'Tag: {tag}, Packet: {packet}')
# Out:
# Tag: {'animal_id': 1, 'session_datetime': datetime.datetime(2023, 10, 1, 12, 0)}, Packet: {'behavior_data': 'path/to/behavior_data_1'}
# Tag: {'animal_id': 2, 'session_datetime': datetime.datetime(2023, 10, 2, 13, 0)}, Packet: {'behavior_data': 'path/to/behavior_data_2'}

# %%
class Test():
    def __init__(self):
        a = []

# %%
x = Test()

# %%
y = Test()

# %%
z = {}

# %%
z[x] = 10

# %%
x == y
# Out:
# False
